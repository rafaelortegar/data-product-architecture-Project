# %%
import boto3
import pandas as pd

# %%
import json

# %%
import datetime

# %%
from luigi.contrib.postgres import CopyToTable
# Out:
# Loading postgres module without psycopg2 installed. Will crash at runtime if postgres functionality is used.

# %%
#import psycopg2

# %%
f = pd.DataFrame(columns=["anio", "estacion", "fecha", "linea", "afluencia"]) # 6

#anio', 'estacion', 'fecha', 'linea', 'afluencia'

# %%
df = pd.read_json(r'metro_2019-01-01.json',encoding='utf-8', orient='values', lines=True)# ,col=["fecha", "anio", "linea", "estacion", "afluencia"]) # 1

# %%
df
# Out:
#    nhits                                         parameters  \
# 0    195  {'dataset': 'afluencia-diaria-del-metro-cdmx',...
#
#                                              records  \
# 0  [{'datasetid': 'afluencia-diaria-del-metro-cdm...
#
#                                         facet_groups
# 0  [{'facets': [{'count': 195, 'path': '2019', 's...

# %%
dfrec=df['records'][0] # 2
dfrec[0]
# Out:
# {'datasetid': 'afluencia-diaria-del-metro-cdmx',
#  'recordid': 'ec33a8dcf83dba40ce9b09e1f51f67acefe1a0ef',
#  'fields': {'anio': '2019',
#   'estacion': 'Pantitlán',
#   'fecha': '2019-01-01',
#   'linea': 'Linea 1',
#   'afluencia': '14452'},
#  'record_timestamp': '2020-03-25T17:13:11.354000+00:00'}

# %%
json_str = json.dumps(dfrec[1])  # aqui va el for # 3

# %%
json_str
# Out:
# '{"datasetid": "afluencia-diaria-del-metro-cdmx", "recordid": "400086b6463bbfe0151467f1e9ace23c6e4e5781", "fields": {"anio": "2019", "estacion": "Zaragoza", "fecha": "2019-01-01", "linea": "Linea 1", "afluencia": "22076"}, "record_timestamp": "2020-03-25T17:13:11.354000+00:00"}'

# %%
el_json=pd.read_json(json_str,orient='index',encoding='utf-8') # 4
el_json
# Out:
#                                                                   0
# datasetid                           afluencia-diaria-del-metro-cdmx
# recordid                   400086b6463bbfe0151467f1e9ace23c6e4e5781
# fields            {'anio': '2019', 'estacion': 'Zaragoza', 'fech...
# record_timestamp                   2020-03-25T17:13:11.354000+00:00

# %%
a_ver = (el_json.loc['fields'][0]) #5
a_ver
# Out:
# {'anio': '2019',
#  'estacion': 'Zaragoza',
#  'fecha': '2019-01-01',
#  'linea': 'Linea 1',
#  'afluencia': '22076'}

# %%
nuevo=pd.DataFrame(a_ver,index=[0]) # 7

# %%
f.append(nuevo) # 8
# Out:
#    anio  estacion       fecha    linea afluencia
# 0  2019  Zaragoza  2019-01-01  Linea 1     22076

# %%
#for i in range(len(list(dfrec))):
#    print(dfrec[i])

# %%
f = pd.DataFrame(columns=["anio", "estacion", "fecha", "linea", "afluencia"])
df = pd.read_json(r'metro_2019-01-01.json',encoding='utf-8', orient='values', lines=True)
dfrec=df['records'][0]
df_aux = f
for x in range(len(list(dfrec))):
    print(x)
    json_str = json.dumps(dfrec[x])
    print("json_str:",json_str)
    print('\n')
    el_json=pd.read_json(json_str,orient='index',encoding='utf-8')
    print("el_json : ", el_json)
    print('\n')
    a_ver = (el_json.loc['fields'][0])
    print("a_ver: ",a_ver)
    print('\n')
    nuevo=pd.DataFrame(a_ver,index=[0])
    print("nuevo: ",nuevo)
    print('\n')
    F f.append(nuevo)
# Out:
# 0
# json_str: {"datasetid": "afluencia-diaria-del-metro-cdmx", "recordid": "ec33a8dcf83dba40ce9b09e1f51f67acefe1a0ef", "fields": {"anio": "2019", "estacion": "Pantitl\u00e1n", "fecha": "2019-01-01", "linea": "Linea 1", "afluencia": "14452"}, "record_timestamp": "2020-03-25T17:13:11.354000+00:00"}
#
#
# el_json :                                                                    0
# datasetid                           afluencia-diaria-del-metro-cdmx
# recordid                   ec33a8dcf83dba40ce9b09e1f51f67acefe1a0ef
# fields            {'anio': '2019', 'estacion': 'Pantitlán', 'fec...
# record_timestamp                   2020-03-25T17:13:11.354000+00:00
#
#
# a_ver:  {'anio': '2019', 'estacion': 'Pantitlán', 'fecha': '2019-01-01', 'linea': 'Linea 1', 'afluencia': '14452'}
#
#
# nuevo:     anio   estacion       fecha    linea afluencia
# 0  2019  Pantitlán  2019-01-01  Linea 1     14452
#
#
# 1
# json_str: {"datasetid": "afluencia-diaria-del-metro-cdmx", "recordid": "400086b6463bbfe0151467f1e9ace23c6e4e5781", "fields": {"anio": "2019", "estacion": "Zaragoza", "fecha": "2019-01-01", "linea": "Linea 1", "afluencia": "22076"}, "record_timestamp": "2020-03-25T17:13:11.354000+00:00"}
#
#
# el_json :                                                                    0
# datasetid                           afluencia-diaria-del-metro-cdmx
# recordid                   400086b6463bbfe0151467f1e9ace23c6e4e5781
# fields            {'anio': '2019', 'estacion': 'Zaragoza', 'fech...
# record_timestamp                   2020-03-25T17:13:11.354000+00:00
#
#
# a_ver:  {'anio': '2019', 'estacion': 'Zaragoza', 'fecha': '2019-01-01', 'linea': 'Linea 1', 'afluencia': '22076'}
#
#
# nuevo:     anio  estacion       fecha    linea afluencia
# 0  2019  Zaragoza  2019-01-01  Linea 1     22076
#
#
# 2
# json_str: {"datasetid": "afluencia-diaria-del-metro-cdmx", "recordid": "25d2093306fd85bc965fb11b8d10b8bce12688aa", "fields": {"anio": "2019", "estacion": "Blvd. Puerto A\u00e9reo", "fecha": "2019-01-01", "linea": "Linea 1", "afluencia": "12613"}, "record_timestamp": "2020-03-25T17:13:11.354000+00:00"}
#
#
# el_json :                                                                    0
# datasetid                           afluencia-diaria-del-metro-cdmx
# recordid                   25d2093306fd85bc965fb11b8d10b8bce12688aa
# fields            {'anio': '2019', 'estacion': 'Blvd. Puerto Aér...
# record_timestamp                   2020-03-25T17:13:11.354000+00:00
#
#
# a_ver:  {'anio': '2019', 'estacion': 'Blvd. Puerto Aéreo', 'fecha': '2019-01-01', 'linea': 'Linea 1', 'afluencia': '12613'}
#
#
# nuevo:     anio            estacion       fecha    linea afluencia
# 0  2019  Blvd. Puerto Aéreo  2019-01-01  Linea 1     12613
#
#
# 3
# json_str: {"datasetid": "afluencia-diaria-del-metro-cdmx", "recordid": "03be6fdf7a75dba96c9d01adf3f517dddf862df1", "fields": {"anio": "2019", "estacion": "Balbuena", "fecha": "2019-01-01", "linea": "Linea 1", "afluencia": "5888"}, "record_timestamp": "2020-03-25T17:13:11.354000+00:00"}
#
#
# el_json :                                                                    0
# datasetid                           afluencia-diaria-del-metro-cdmx
# recordid                   03be6fdf7a75dba96c9d01adf3f517dddf862df1
# fields            {'anio': '2019', 'estacion': 'Balbuena', 'fech...
# record_timestamp                   2020-03-25T17:13:11.354000+00:00
#
#
# a_ver:  {'anio': '2019', 'estacion': 'Balbuena', 'fecha': '2019-01-01', 'linea': 'Linea 1', 'afluencia': '5888'}
#
#
# nuevo:     anio  estacion       fecha    linea afluencia
# 0  2019  Balbuena  2019-01-01  Linea 1      5888
#
#
# 4
# json_str: {"datasetid": "afluencia-diaria-del-metro-cdmx", "recordid": "d404a007e6b846ee058c4b2d2ff4f9f25107ef5e", "fields": {"anio": "2019", "estacion": "Insurgentes", "fecha": "2019-01-01", "linea": "Linea 1", "afluencia": "13832"}, "record_timestamp": "2020-03-25T17:13:11.354000+00:00"}
#
#
# el_json :                                                                    0
# datasetid                           afluencia-diaria-del-metro-cdmx
# recordid                   d404a007e6b846ee058c4b2d2ff4f9f25107ef5e
# fields            {'anio': '2019', 'estacion': 'Insurgentes', 'f...
# record_timestamp                   2020-03-25T17:13:11.354000+00:00
#
#
# a_ver:  {'anio': '2019', 'estacion': 'Insurgentes', 'fecha': '2019-01-01', 'linea': 'Linea 1', 'afluencia': '13832'}
#
#
# nuevo:     anio     estacion       fecha    linea afluencia
# 0  2019  Insurgentes  2019-01-01  Linea 1     13832
#
#
# 5
# json_str: {"datasetid": "afluencia-diaria-del-metro-cdmx", "recordid": "6ea86b05bbeb620de42abdd3f37f90407ebb2218", "fields": {"anio": "2019", "estacion": "Tacubaya", "fecha": "2019-01-01", "linea": "Linea 1", "afluencia": "12914"}, "record_timestamp": "2020-03-25T17:13:11.354000+00:00"}
#
#
# el_json :                                                                    0
# datasetid                           afluencia-diaria-del-metro-cdmx
# recordid                   6ea86b05bbeb620de42abdd3f37f90407ebb2218
# fields            {'anio': '2019', 'estacion': 'Tacubaya', 'fech...
# record_timestamp                   2020-03-25T17:13:11.354000+00:00
#
#
# a_ver:  {'anio': '2019', 'estacion': 'Tacubaya', 'fecha': '2019-01-01', 'linea': 'Linea 1', 'afluencia': '12914'}
#
#
# nuevo:     anio  estacion       fecha    linea afluencia
# 0  2019  Tacubaya  2019-01-01  Linea 1     12914
#
#
# 6
# json_str: {"datasetid": "afluencia-diaria-del-metro-cdmx", "recordid": "f7143133a5866df430af793ade1f7ac14c400b4b", "fields": {"anio": "2019", "estacion": "Cuatro Caminos", "fecha": "2019-01-01", "linea": "Linea 2", "afluencia": "42075"}, "record_timestamp": "2020-03-25T17:13:11.354000+00:00"}
#
#
# el_json :                                                                    0
# datasetid                           afluencia-diaria-del-metro-cdmx
# recordid                   f7143133a5866df430af793ade1f7ac14c400b4b
# fields            {'anio': '2019', 'estacion': 'Cuatro Caminos',...
# record_timestamp                   2020-03-25T17:13:11.354000+00:00
#
#
# a_ver:  {'anio': '2019', 'estacion': 'Cuatro Caminos', 'fecha': '2019-01-01', 'linea': 'Linea 2', 'afluencia': '42075'}
#
#
# nuevo:     anio        estacion       fecha    linea afluencia
# 0  2019  Cuatro Caminos  2019-01-01  Linea 2     42075
#
#
# 7
# json_str: {"datasetid": "afluencia-diaria-del-metro-cdmx", "recordid": "e76388bcbbeaf9b166a55440d531f2dc4fa16285", "fields": {"anio": "2019", "estacion": "Bellas Artes", "fecha": "2019-01-01", "linea": "Linea 2", "afluencia": "17681"}, "record_timestamp": "2020-03-25T17:13:11.354000+00:00"}
#
#
# el_json :                                                                    0
# datasetid                           afluencia-diaria-del-metro-cdmx
# recordid                   e76388bcbbeaf9b166a55440d531f2dc4fa16285
# fields            {'anio': '2019', 'estacion': 'Bellas Artes', '...
# record_timestamp                   2020-03-25T17:13:11.354000+00:00
#
#
# a_ver:  {'anio': '2019', 'estacion': 'Bellas Artes', 'fecha': '2019-01-01', 'linea': 'Linea 2', 'afluencia': '17681'}
#
#
# nuevo:     anio      estacion       fecha    linea afluencia
# 0  2019  Bellas Artes  2019-01-01  Linea 2     17681
#
#
# 8
# json_str: {"datasetid": "afluencia-diaria-del-metro-cdmx", "recordid": "6eb8466949b2e849eb5b929256123809cd20a679", "fields": {"anio": "2019", "estacion": "Nativitas", "fecha": "2019-01-01", "linea": "Linea 2", "afluencia": "14110"}, "record_timestamp": "2020-03-25T17:13:11.354000+00:00"}
#
#
# el_json :                                                                    0
# datasetid                           afluencia-diaria-del-metro-cdmx
# recordid                   6eb8466949b2e849eb5b929256123809cd20a679
# fields            {'anio': '2019', 'estacion': 'Nativitas', 'fec...
# record_timestamp                   2020-03-25T17:13:11.354000+00:00
#
#
# a_ver:  {'anio': '2019', 'estacion': 'Nativitas', 'fecha': '2019-01-01', 'linea': 'Linea 2', 'afluencia': '14110'}
#
#
# nuevo:     anio   estacion       fecha    linea afluencia
# 0  2019  Nativitas  2019-01-01  Linea 2     14110
#
#
# 9
# json_str: {"datasetid": "afluencia-diaria-del-metro-cdmx", "recordid": "d264ec00ca87bf1d5c58e3eaf6243b0614bd3475", "fields": {"anio": "2019", "estacion": "Portales", "fecha": "2019-01-01", "linea": "Linea 2", "afluencia": "8291"}, "record_timestamp": "2020-03-25T17:13:11.354000+00:00"}
#
#
# el_json :                                                                    0
# datasetid                           afluencia-diaria-del-metro-cdmx
# recordid                   d264ec00ca87bf1d5c58e3eaf6243b0614bd3475
# fields            {'anio': '2019', 'estacion': 'Portales', 'fech...
# record_timestamp                   2020-03-25T17:13:11.354000+00:00
#
#
# a_ver:  {'anio': '2019', 'estacion': 'Portales', 'fecha': '2019-01-01', 'linea': 'Linea 2', 'afluencia': '8291'}
#
#
# nuevo:     anio  estacion       fecha    linea afluencia
# 0  2019  Portales  2019-01-01  Linea 2      8291
#
#
# 10
# json_str: {"datasetid": "afluencia-diaria-del-metro-cdmx", "recordid": "09ca9b6cb16e0b446852cb6919e041db24b7a5bb", "fields": {"anio": "2019", "estacion": "Ermita", "fecha": "2019-01-01", "linea": "Linea 2", "afluencia": "4378"}, "record_timestamp": "2020-03-25T17:13:11.354000+00:00"}
#
#
# el_json :                                                                    0
# datasetid                           afluencia-diaria-del-metro-cdmx
# recordid                   09ca9b6cb16e0b446852cb6919e041db24b7a5bb
# fields            {'anio': '2019', 'estacion': 'Ermita', 'fecha'...
# record_timestamp                   2020-03-25T17:13:11.354000+00:00
#
#
# a_ver:  {'anio': '2019', 'estacion': 'Ermita', 'fecha': '2019-01-01', 'linea': 'Linea 2', 'afluencia': '4378'}
#
#
# nuevo:     anio estacion       fecha    linea afluencia
# 0  2019   Ermita  2019-01-01  Linea 2      4378
#
#
# 11
# json_str: {"datasetid": "afluencia-diaria-del-metro-cdmx", "recordid": "f758e47c932b6f1ce0ca0cee0becb2a27e11419d", "fields": {"anio": "2019", "estacion": "Indios Verdes", "fecha": "2019-01-01", "linea": "Linea 3", "afluencia": "37249"}, "record_timestamp": "2020-03-25T17:13:11.354000+00:00"}
#
#
# el_json :                                                                    0
# datasetid                           afluencia-diaria-del-metro-cdmx
# recordid                   f758e47c932b6f1ce0ca0cee0becb2a27e11419d
# fields            {'anio': '2019', 'estacion': 'Indios Verdes', ...
# record_timestamp                   2020-03-25T17:13:11.354000+00:00
#
#
# a_ver:  {'anio': '2019', 'estacion': 'Indios Verdes', 'fecha': '2019-01-01', 'linea': 'Linea 3', 'afluencia': '37249'}
#
#
# nuevo:     anio       estacion       fecha    linea afluencia
# 0  2019  Indios Verdes  2019-01-01  Linea 3     37249
#
#
# 12
# json_str: {"datasetid": "afluencia-diaria-del-metro-cdmx", "recordid": "cc8a1b964c8525b67f5f78a52815d9b7c6797f97", "fields": {"anio": "2019", "estacion": "La Raza", "fecha": "2019-01-01", "linea": "Linea 3", "afluencia": "9007"}, "record_timestamp": "2020-03-25T17:13:11.354000+00:00"}
#
#
# el_json :                                                                    0
# datasetid                           afluencia-diaria-del-metro-cdmx
# recordid                   cc8a1b964c8525b67f5f78a52815d9b7c6797f97
# fields            {'anio': '2019', 'estacion': 'La Raza', 'fecha...
# record_timestamp                   2020-03-25T17:13:11.354000+00:00
#
#
# a_ver:  {'anio': '2019', 'estacion': 'La Raza', 'fecha': '2019-01-01', 'linea': 'Linea 3', 'afluencia': '9007'}
#
#
# nuevo:     anio estacion       fecha    linea afluencia
# 0  2019  La Raza  2019-01-01  Linea 3      9007
#
#
# 13
# json_str: {"datasetid": "afluencia-diaria-del-metro-cdmx", "recordid": "0630580c20c732ab2fa27da6b064164c71146999", "fields": {"anio": "2019", "estacion": "Guerrero", "fecha": "2019-01-01", "linea": "Linea 3", "afluencia": "4662"}, "record_timestamp": "2020-03-25T17:13:11.354000+00:00"}
#
#
# el_json :                                                                    0
# datasetid                           afluencia-diaria-del-metro-cdmx
# recordid                   0630580c20c732ab2fa27da6b064164c71146999
# fields            {'anio': '2019', 'estacion': 'Guerrero', 'fech...
# record_timestamp                   2020-03-25T17:13:11.354000+00:00
#
#
# a_ver:  {'anio': '2019', 'estacion': 'Guerrero', 'fecha': '2019-01-01', 'linea': 'Linea 3', 'afluencia': '4662'}
#
#
# nuevo:     anio  estacion       fecha    linea afluencia
# 0  2019  Guerrero  2019-01-01  Linea 3      4662
#
#
# 14
# json_str: {"datasetid": "afluencia-diaria-del-metro-cdmx", "recordid": "d0307b99b7eca99e05407c5a55569567ef267ccb", "fields": {"anio": "2019", "estacion": "Hidalgo", "fecha": "2019-01-01", "linea": "Linea 3", "afluencia": "7831"}, "record_timestamp": "2020-03-25T17:13:11.354000+00:00"}
#
#
# el_json :                                                                    0
# datasetid                           afluencia-diaria-del-metro-cdmx
# recordid                   d0307b99b7eca99e05407c5a55569567ef267ccb
# fields            {'anio': '2019', 'estacion': 'Hidalgo', 'fecha...
# record_timestamp                   2020-03-25T17:13:11.354000+00:00
#
#
# a_ver:  {'anio': '2019', 'estacion': 'Hidalgo', 'fecha': '2019-01-01', 'linea': 'Linea 3', 'afluencia': '7831'}
#
#
# nuevo:     anio estacion       fecha    linea afluencia
# 0  2019  Hidalgo  2019-01-01  Linea 3      7831
#
#
# 15
# json_str: {"datasetid": "afluencia-diaria-del-metro-cdmx", "recordid": "b99bed46794da2256d3871ee0fb4681035cd2d83", "fields": {"anio": "2019", "estacion": "Ju\u00e1rez", "fecha": "2019-01-01", "linea": "Linea 3", "afluencia": "3215"}, "record_timestamp": "2020-03-25T17:13:11.354000+00:00"}
#
#
# el_json :                                                                    0
# datasetid                           afluencia-diaria-del-metro-cdmx
# recordid                   b99bed46794da2256d3871ee0fb4681035cd2d83
# fields            {'anio': '2019', 'estacion': 'Juárez', 'fecha'...
# record_timestamp                   2020-03-25T17:13:11.354000+00:00
#
#
# a_ver:  {'anio': '2019', 'estacion': 'Juárez', 'fecha': '2019-01-01', 'linea': 'Linea 3', 'afluencia': '3215'}
#
#
# nuevo:     anio estacion       fecha    linea afluencia
# 0  2019   Juárez  2019-01-01  Linea 3      3215
#
#
# 16
# json_str: {"datasetid": "afluencia-diaria-del-metro-cdmx", "recordid": "de3fb176ba4b635bd9e29abad6f76a0cbffe8dd0", "fields": {"anio": "2019", "estacion": "Zapata", "fecha": "2019-01-01", "linea": "Linea 3", "afluencia": "6032"}, "record_timestamp": "2020-03-25T17:13:11.354000+00:00"}
#
#
# el_json :                                                                    0
# datasetid                           afluencia-diaria-del-metro-cdmx
# recordid                   de3fb176ba4b635bd9e29abad6f76a0cbffe8dd0
# fields            {'anio': '2019', 'estacion': 'Zapata', 'fecha'...
# record_timestamp                   2020-03-25T17:13:11.354000+00:00
#
#
# a_ver:  {'anio': '2019', 'estacion': 'Zapata', 'fecha': '2019-01-01', 'linea': 'Linea 3', 'afluencia': '6032'}
#
#
# nuevo:     anio estacion       fecha    linea afluencia
# 0  2019   Zapata  2019-01-01  Linea 3      6032
#
#
# 17
# json_str: {"datasetid": "afluencia-diaria-del-metro-cdmx", "recordid": "502c891bc6216e30dee21fc7a37b672ebf0d539c", "fields": {"anio": "2019", "estacion": "Coyoac\u00e1n", "fecha": "2019-01-01", "linea": "Linea 3", "afluencia": "5922"}, "record_timestamp": "2020-03-25T17:13:11.354000+00:00"}
#
#
# el_json :                                                                    0
# datasetid                           afluencia-diaria-del-metro-cdmx
# recordid                   502c891bc6216e30dee21fc7a37b672ebf0d539c
# fields            {'anio': '2019', 'estacion': 'Coyoacán', 'fech...
# record_timestamp                   2020-03-25T17:13:11.354000+00:00
#
#
# a_ver:  {'anio': '2019', 'estacion': 'Coyoacán', 'fecha': '2019-01-01', 'linea': 'Linea 3', 'afluencia': '5922'}
#
#
# nuevo:     anio  estacion       fecha    linea afluencia
# 0  2019  Coyoacán  2019-01-01  Linea 3      5922
#
#
# 18
# json_str: {"datasetid": "afluencia-diaria-del-metro-cdmx", "recordid": "cfecbbd2643138030afaf3bf3c7921c9f8d07eff", "fields": {"anio": "2019", "estacion": "Universidad", "fecha": "2019-01-01", "linea": "Linea 3", "afluencia": "18486"}, "record_timestamp": "2020-03-25T17:13:11.354000+00:00"}
#
#
# el_json :                                                                    0
# datasetid                           afluencia-diaria-del-metro-cdmx
# recordid                   cfecbbd2643138030afaf3bf3c7921c9f8d07eff
# fields            {'anio': '2019', 'estacion': 'Universidad', 'f...
# record_timestamp                   2020-03-25T17:13:11.354000+00:00
#
#
# a_ver:  {'anio': '2019', 'estacion': 'Universidad', 'fecha': '2019-01-01', 'linea': 'Linea 3', 'afluencia': '18486'}
#
#
# nuevo:     anio     estacion       fecha    linea afluencia
# 0  2019  Universidad  2019-01-01  Linea 3     18486
#
#
# 19
# json_str: {"datasetid": "afluencia-diaria-del-metro-cdmx", "recordid": "6a6e23f2f400d48ff588e6db7e51e95f776698e7", "fields": {"anio": "2019", "estacion": "Morelos", "fecha": "2019-01-01", "linea": "Linea 4", "afluencia": "3119"}, "record_timestamp": "2020-03-25T17:13:11.354000+00:00"}
#
#
# el_json :                                                                    0
# datasetid                           afluencia-diaria-del-metro-cdmx
# recordid                   6a6e23f2f400d48ff588e6db7e51e95f776698e7
# fields            {'anio': '2019', 'estacion': 'Morelos', 'fecha...
# record_timestamp                   2020-03-25T17:13:11.354000+00:00
#
#
# a_ver:  {'anio': '2019', 'estacion': 'Morelos', 'fecha': '2019-01-01', 'linea': 'Linea 4', 'afluencia': '3119'}
#
#
# nuevo:     anio estacion       fecha    linea afluencia
# 0  2019  Morelos  2019-01-01  Linea 4      3119
#
#
# 20
# json_str: {"datasetid": "afluencia-diaria-del-metro-cdmx", "recordid": "a4a80487e603ae9e1d408d5eb0a03e7d3ef684ef", "fields": {"anio": "2019", "estacion": "Bondojito", "fecha": "2019-01-01", "linea": "Linea 4", "afluencia": "2295"}, "record_timestamp": "2020-03-25T17:13:11.354000+00:00"}
#
#
# el_json :                                                                    0
# datasetid                           afluencia-diaria-del-metro-cdmx
# recordid                   a4a80487e603ae9e1d408d5eb0a03e7d3ef684ef
# fields            {'anio': '2019', 'estacion': 'Bondojito', 'fec...
# record_timestamp                   2020-03-25T17:13:11.354000+00:00
#
#
# a_ver:  {'anio': '2019', 'estacion': 'Bondojito', 'fecha': '2019-01-01', 'linea': 'Linea 4', 'afluencia': '2295'}
#
#
# nuevo:     anio   estacion       fecha    linea afluencia
# 0  2019  Bondojito  2019-01-01  Linea 4      2295
#
#
# 21
# json_str: {"datasetid": "afluencia-diaria-del-metro-cdmx", "recordid": "f1a9671ecad351c038e41bda7cdff20e2c6577af", "fields": {"anio": "2019", "estacion": "Consulado", "fecha": "2019-01-01", "linea": "Linea 5", "afluencia": "1686"}, "record_timestamp": "2020-03-25T17:13:11.354000+00:00"}
#
#
# el_json :                                                                    0
# datasetid                           afluencia-diaria-del-metro-cdmx
# recordid                   f1a9671ecad351c038e41bda7cdff20e2c6577af
# fields            {'anio': '2019', 'estacion': 'Consulado', 'fec...
# record_timestamp                   2020-03-25T17:13:11.354000+00:00
#
#
# a_ver:  {'anio': '2019', 'estacion': 'Consulado', 'fecha': '2019-01-01', 'linea': 'Linea 5', 'afluencia': '1686'}
#
#
# nuevo:     anio   estacion       fecha    linea afluencia
# 0  2019  Consulado  2019-01-01  Linea 5      1686
#
#
# 22
# json_str: {"datasetid": "afluencia-diaria-del-metro-cdmx", "recordid": "f703aca494a020ce1c63028554b59a14b1232e8e", "fields": {"anio": "2019", "estacion": "Terminal A\u00e9rea", "fecha": "2019-01-01", "linea": "Linea 5", "afluencia": "9900"}, "record_timestamp": "2020-03-25T17:13:11.354000+00:00"}
#
#
# el_json :                                                                    0
# datasetid                           afluencia-diaria-del-metro-cdmx
# recordid                   f703aca494a020ce1c63028554b59a14b1232e8e
# fields            {'anio': '2019', 'estacion': 'Terminal Aérea',...
# record_timestamp                   2020-03-25T17:13:11.354000+00:00
#
#
# a_ver:  {'anio': '2019', 'estacion': 'Terminal Aérea', 'fecha': '2019-01-01', 'linea': 'Linea 5', 'afluencia': '9900'}
#
#
# nuevo:     anio        estacion       fecha    linea afluencia
# 0  2019  Terminal Aérea  2019-01-01  Linea 5      9900
#
#
# 23
# json_str: {"datasetid": "afluencia-diaria-del-metro-cdmx", "recordid": "f95507f37f688f91d211a4fc6661409d792b67e8", "fields": {"anio": "2019", "estacion": "Pantitl\u00e1n", "fecha": "2019-01-01", "linea": "Linea 5", "afluencia": "63312"}, "record_timestamp": "2020-03-25T17:13:11.354000+00:00"}
#
#
# el_json :                                                                    0
# datasetid                           afluencia-diaria-del-metro-cdmx
# recordid                   f95507f37f688f91d211a4fc6661409d792b67e8
# fields            {'anio': '2019', 'estacion': 'Pantitlán', 'fec...
# record_timestamp                   2020-03-25T17:13:11.354000+00:00
#
#
# a_ver:  {'anio': '2019', 'estacion': 'Pantitlán', 'fecha': '2019-01-01', 'linea': 'Linea 5', 'afluencia': '63312'}
#
#
# nuevo:     anio   estacion       fecha    linea afluencia
# 0  2019  Pantitlán  2019-01-01  Linea 5     63312
#
#
# 24
# json_str: {"datasetid": "afluencia-diaria-del-metro-cdmx", "recordid": "cdf368530741495f3bcec96977cb8ad240543d0b", "fields": {"anio": "2019", "estacion": "Lindavista", "fecha": "2019-01-01", "linea": "Linea 6", "afluencia": "4211"}, "record_timestamp": "2020-03-25T17:13:11.354000+00:00"}
#
#
# el_json :                                                                    0
# datasetid                           afluencia-diaria-del-metro-cdmx
# recordid                   cdf368530741495f3bcec96977cb8ad240543d0b
# fields            {'anio': '2019', 'estacion': 'Lindavista', 'fe...
# record_timestamp                   2020-03-25T17:13:11.354000+00:00
#
#
# a_ver:  {'anio': '2019', 'estacion': 'Lindavista', 'fecha': '2019-01-01', 'linea': 'Linea 6', 'afluencia': '4211'}
#
#
# nuevo:     anio    estacion       fecha    linea afluencia
# 0  2019  Lindavista  2019-01-01  Linea 6      4211
#
#
# 25
# json_str: {"datasetid": "afluencia-diaria-del-metro-cdmx", "recordid": "09f66f0289d03b2ebc55e0e26a62336126524f31", "fields": {"anio": "2019", "estacion": "Deptvo. 18 de Marzo", "fecha": "2019-01-01", "linea": "Linea 6", "afluencia": "558"}, "record_timestamp": "2020-03-25T17:13:11.354000+00:00"}
#
#
# el_json :                                                                    0
# datasetid                           afluencia-diaria-del-metro-cdmx
# recordid                   09f66f0289d03b2ebc55e0e26a62336126524f31
# fields            {'anio': '2019', 'estacion': 'Deptvo. 18 de Ma...
# record_timestamp                   2020-03-25T17:13:11.354000+00:00
#
#
# a_ver:  {'anio': '2019', 'estacion': 'Deptvo. 18 de Marzo', 'fecha': '2019-01-01', 'linea': 'Linea 6', 'afluencia': '558'}
#
#
# nuevo:     anio             estacion       fecha    linea afluencia
# 0  2019  Deptvo. 18 de Marzo  2019-01-01  Linea 6       558
#
#
# 26
# json_str: {"datasetid": "afluencia-diaria-del-metro-cdmx", "recordid": "81d99ef3b9bc83448adcfcc0257836cfe4f24f1b", "fields": {"anio": "2019", "estacion": "La Villa-Basilica", "fecha": "2019-01-01", "linea": "Linea 6", "afluencia": "28197"}, "record_timestamp": "2020-03-25T17:13:11.354000+00:00"}
#
#
# el_json :                                                                    0
# datasetid                           afluencia-diaria-del-metro-cdmx
# recordid                   81d99ef3b9bc83448adcfcc0257836cfe4f24f1b
# fields            {'anio': '2019', 'estacion': 'La Villa-Basilic...
# record_timestamp                   2020-03-25T17:13:11.354000+00:00
#
#
# a_ver:  {'anio': '2019', 'estacion': 'La Villa-Basilica', 'fecha': '2019-01-01', 'linea': 'Linea 6', 'afluencia': '28197'}
#
#
# nuevo:     anio           estacion       fecha    linea afluencia
# 0  2019  La Villa-Basilica  2019-01-01  Linea 6     28197
#
#
# 27
# json_str: {"datasetid": "afluencia-diaria-del-metro-cdmx", "recordid": "eb7af1b0b8e7c8e329828f3907d5c114f230f5bd", "fields": {"anio": "2019", "estacion": "Mart\u00edn Carrera", "fecha": "2019-01-01", "linea": "Linea 6", "afluencia": "7913"}, "record_timestamp": "2020-03-25T17:13:11.354000+00:00"}
#
#
# el_json :                                                                    0
# datasetid                           afluencia-diaria-del-metro-cdmx
# recordid                   eb7af1b0b8e7c8e329828f3907d5c114f230f5bd
# fields            {'anio': '2019', 'estacion': 'Martín Carrera',...
# record_timestamp                   2020-03-25T17:13:11.354000+00:00
#
#
# a_ver:  {'anio': '2019', 'estacion': 'Martín Carrera', 'fecha': '2019-01-01', 'linea': 'Linea 6', 'afluencia': '7913'}
#
#
# nuevo:     anio        estacion       fecha    linea afluencia
# 0  2019  Martín Carrera  2019-01-01  Linea 6      7913
#
#
# 28
# json_str: {"datasetid": "afluencia-diaria-del-metro-cdmx", "recordid": "b1216efc88bc86db80b0b7ec0469de2e226e04ef", "fields": {"anio": "2019", "estacion": "El Rosario", "fecha": "2019-01-01", "linea": "Linea 7", "afluencia": "11986"}, "record_timestamp": "2020-03-25T17:13:11.354000+00:00"}
#
#
# el_json :                                                                    0
# datasetid                           afluencia-diaria-del-metro-cdmx
# recordid                   b1216efc88bc86db80b0b7ec0469de2e226e04ef
# fields            {'anio': '2019', 'estacion': 'El Rosario', 'fe...
# record_timestamp                   2020-03-25T17:13:11.354000+00:00
#
#
# a_ver:  {'anio': '2019', 'estacion': 'El Rosario', 'fecha': '2019-01-01', 'linea': 'Linea 7', 'afluencia': '11986'}
#
#
# nuevo:     anio    estacion       fecha    linea afluencia
# 0  2019  El Rosario  2019-01-01  Linea 7     11986
#
#
# 29
# json_str: {"datasetid": "afluencia-diaria-del-metro-cdmx", "recordid": "aad5f12194b2f7190fed1621230dbf6a2b33321b", "fields": {"anio": "2019", "estacion": "San Joaqu\u00edn", "fecha": "2019-01-01", "linea": "Linea 7", "afluencia": "6915"}, "record_timestamp": "2020-03-25T17:13:11.354000+00:00"}
#
#
# el_json :                                                                    0
# datasetid                           afluencia-diaria-del-metro-cdmx
# recordid                   aad5f12194b2f7190fed1621230dbf6a2b33321b
# fields            {'anio': '2019', 'estacion': 'San Joaquín', 'f...
# record_timestamp                   2020-03-25T17:13:11.354000+00:00
#
#
# a_ver:  {'anio': '2019', 'estacion': 'San Joaquín', 'fecha': '2019-01-01', 'linea': 'Linea 7', 'afluencia': '6915'}
#
#
# nuevo:     anio     estacion       fecha    linea afluencia
# 0  2019  San Joaquín  2019-01-01  Linea 7      6915
#
#
# 30
# json_str: {"datasetid": "afluencia-diaria-del-metro-cdmx", "recordid": "52e8374c82f4481adbbd3a79c84a3f90bfda5188", "fields": {"anio": "2019", "estacion": "Polanco", "fecha": "2019-01-01", "linea": "Linea 7", "afluencia": "6610"}, "record_timestamp": "2020-03-25T17:13:11.354000+00:00"}
#
#
# el_json :                                                                    0
# datasetid                           afluencia-diaria-del-metro-cdmx
# recordid                   52e8374c82f4481adbbd3a79c84a3f90bfda5188
# fields            {'anio': '2019', 'estacion': 'Polanco', 'fecha...
# record_timestamp                   2020-03-25T17:13:11.354000+00:00
#
#
# a_ver:  {'anio': '2019', 'estacion': 'Polanco', 'fecha': '2019-01-01', 'linea': 'Linea 7', 'afluencia': '6610'}
#
#
# nuevo:     anio estacion       fecha    linea afluencia
# 0  2019  Polanco  2019-01-01  Linea 7      6610
#
#
# 31
# json_str: {"datasetid": "afluencia-diaria-del-metro-cdmx", "recordid": "82f0a74ad753fff3caa7fa36eb1fe897d51372a8", "fields": {"anio": "2019", "estacion": "Barranca del Muerto", "fecha": "2019-01-01", "linea": "Linea 7", "afluencia": "7936"}, "record_timestamp": "2020-03-25T17:13:11.354000+00:00"}
#
#
# el_json :                                                                    0
# datasetid                           afluencia-diaria-del-metro-cdmx
# recordid                   82f0a74ad753fff3caa7fa36eb1fe897d51372a8
# fields            {'anio': '2019', 'estacion': 'Barranca del Mue...
# record_timestamp                   2020-03-25T17:13:11.354000+00:00
#
#
# a_ver:  {'anio': '2019', 'estacion': 'Barranca del Muerto', 'fecha': '2019-01-01', 'linea': 'Linea 7', 'afluencia': '7936'}
#
#
# nuevo:     anio             estacion       fecha    linea afluencia
# 0  2019  Barranca del Muerto  2019-01-01  Linea 7      7936
#
#
# 32
# json_str: {"datasetid": "afluencia-diaria-del-metro-cdmx", "recordid": "7d0bc8b9ed9f02770fef9719ccbf07302da6c922", "fields": {"anio": "2019", "estacion": "Garibaldi", "fecha": "2019-01-01", "linea": "Linea 8", "afluencia": "7658"}, "record_timestamp": "2020-03-25T17:13:11.354000+00:00"}
#
#
# el_json :                                                                    0
# datasetid                           afluencia-diaria-del-metro-cdmx
# recordid                   7d0bc8b9ed9f02770fef9719ccbf07302da6c922
# fields            {'anio': '2019', 'estacion': 'Garibaldi', 'fec...
# record_timestamp                   2020-03-25T17:13:11.354000+00:00
#
#
# a_ver:  {'anio': '2019', 'estacion': 'Garibaldi', 'fecha': '2019-01-01', 'linea': 'Linea 8', 'afluencia': '7658'}
#
#
# nuevo:     anio   estacion       fecha    linea afluencia
# 0  2019  Garibaldi  2019-01-01  Linea 8      7658
#
#
# 33
# json_str: {"datasetid": "afluencia-diaria-del-metro-cdmx", "recordid": "ff601942d4bab39b097c32767e773465492c8ad5", "fields": {"anio": "2019", "estacion": "Salto del Agua", "fecha": "2019-01-01", "linea": "Linea 8", "afluencia": "3284"}, "record_timestamp": "2020-03-25T17:13:11.354000+00:00"}
#
#
# el_json :                                                                    0
# datasetid                           afluencia-diaria-del-metro-cdmx
# recordid                   ff601942d4bab39b097c32767e773465492c8ad5
# fields            {'anio': '2019', 'estacion': 'Salto del Agua',...
# record_timestamp                   2020-03-25T17:13:11.354000+00:00
#
#
# a_ver:  {'anio': '2019', 'estacion': 'Salto del Agua', 'fecha': '2019-01-01', 'linea': 'Linea 8', 'afluencia': '3284'}
#
#
# nuevo:     anio        estacion       fecha    linea afluencia
# 0  2019  Salto del Agua  2019-01-01  Linea 8      3284
#
#
# 34
# json_str: {"datasetid": "afluencia-diaria-del-metro-cdmx", "recordid": "72bffd4853fd739760f9aa55d5f7ec354ab666e8", "fields": {"anio": "2019", "estacion": "Doctores", "fecha": "2019-01-01", "linea": "Linea 8", "afluencia": "2546"}, "record_timestamp": "2020-03-25T17:13:11.354000+00:00"}
#
#
# el_json :                                                                    0
# datasetid                           afluencia-diaria-del-metro-cdmx
# recordid                   72bffd4853fd739760f9aa55d5f7ec354ab666e8
# fields            {'anio': '2019', 'estacion': 'Doctores', 'fech...
# record_timestamp                   2020-03-25T17:13:11.354000+00:00
#
#
# a_ver:  {'anio': '2019', 'estacion': 'Doctores', 'fecha': '2019-01-01', 'linea': 'Linea 8', 'afluencia': '2546'}
#
#
# nuevo:     anio  estacion       fecha    linea afluencia
# 0  2019  Doctores  2019-01-01  Linea 8      2546
#
#
# 35
# json_str: {"datasetid": "afluencia-diaria-del-metro-cdmx", "recordid": "a1c29463af58f36deabd8fb23e82cd74698f5a94", "fields": {"anio": "2019", "estacion": "La Viga", "fecha": "2019-01-01", "linea": "Linea 8", "afluencia": "2457"}, "record_timestamp": "2020-03-25T17:13:11.354000+00:00"}
#
#
# el_json :                                                                    0
# datasetid                           afluencia-diaria-del-metro-cdmx
# recordid                   a1c29463af58f36deabd8fb23e82cd74698f5a94
# fields            {'anio': '2019', 'estacion': 'La Viga', 'fecha...
# record_timestamp                   2020-03-25T17:13:11.354000+00:00
#
#
# a_ver:  {'anio': '2019', 'estacion': 'La Viga', 'fecha': '2019-01-01', 'linea': 'Linea 8', 'afluencia': '2457'}
#
#
# nuevo:     anio estacion       fecha    linea afluencia
# 0  2019  La Viga  2019-01-01  Linea 8      2457
#
#
# 36
# json_str: {"datasetid": "afluencia-diaria-del-metro-cdmx", "recordid": "83b07946343ec0cda16cace0bbca359c1cc0342a", "fields": {"anio": "2019", "estacion": "Iztacalco", "fecha": "2019-01-01", "linea": "Linea 8", "afluencia": "6377"}, "record_timestamp": "2020-03-25T17:13:11.354000+00:00"}
#
#
# el_json :                                                                    0
# datasetid                           afluencia-diaria-del-metro-cdmx
# recordid                   83b07946343ec0cda16cace0bbca359c1cc0342a
# fields            {'anio': '2019', 'estacion': 'Iztacalco', 'fec...
# record_timestamp                   2020-03-25T17:13:11.354000+00:00
#
#
# a_ver:  {'anio': '2019', 'estacion': 'Iztacalco', 'fecha': '2019-01-01', 'linea': 'Linea 8', 'afluencia': '6377'}
#
#
# nuevo:     anio   estacion       fecha    linea afluencia
# 0  2019  Iztacalco  2019-01-01  Linea 8      6377
#
#
# 37
# json_str: {"datasetid": "afluencia-diaria-del-metro-cdmx", "recordid": "0c8cb4eabdc60479a7445c50568513d6a2f61130", "fields": {"anio": "2019", "estacion": "Aculco", "fecha": "2019-01-01", "linea": "Linea 8", "afluencia": "3235"}, "record_timestamp": "2020-03-25T17:13:11.354000+00:00"}
#
#
# el_json :                                                                    0
# datasetid                           afluencia-diaria-del-metro-cdmx
# recordid                   0c8cb4eabdc60479a7445c50568513d6a2f61130
# fields            {'anio': '2019', 'estacion': 'Aculco', 'fecha'...
# record_timestamp                   2020-03-25T17:13:11.354000+00:00
#
#
# a_ver:  {'anio': '2019', 'estacion': 'Aculco', 'fecha': '2019-01-01', 'linea': 'Linea 8', 'afluencia': '3235'}
#
#
# nuevo:     anio estacion       fecha    linea afluencia
# 0  2019   Aculco  2019-01-01  Linea 8      3235
#
#
# 38
# json_str: {"datasetid": "afluencia-diaria-del-metro-cdmx", "recordid": "57105fb0438a47c4c10a4921712ea9a06a49b770", "fields": {"anio": "2019", "estacion": "Escuadr\u00f3n 201", "fecha": "2019-01-01", "linea": "Linea 8", "afluencia": "9860"}, "record_timestamp": "2020-03-25T17:13:11.354000+00:00"}
#
#
# el_json :                                                                    0
# datasetid                           afluencia-diaria-del-metro-cdmx
# recordid                   57105fb0438a47c4c10a4921712ea9a06a49b770
# fields            {'anio': '2019', 'estacion': 'Escuadrón 201', ...
# record_timestamp                   2020-03-25T17:13:11.354000+00:00
#
#
# a_ver:  {'anio': '2019', 'estacion': 'Escuadrón 201', 'fecha': '2019-01-01', 'linea': 'Linea 8', 'afluencia': '9860'}
#
#
# nuevo:     anio       estacion       fecha    linea afluencia
# 0  2019  Escuadrón 201  2019-01-01  Linea 8      9860
#
#
# 39
# json_str: {"datasetid": "afluencia-diaria-del-metro-cdmx", "recordid": "dfdefb6b3157bcfb74337c5bed9247c19b8b03b9", "fields": {"anio": "2019", "estacion": "Atlalilco", "fecha": "2019-01-01", "linea": "Linea 8", "afluencia": "6813"}, "record_timestamp": "2020-03-25T17:13:11.354000+00:00"}
#
#
# el_json :                                                                    0
# datasetid                           afluencia-diaria-del-metro-cdmx
# recordid                   dfdefb6b3157bcfb74337c5bed9247c19b8b03b9
# fields            {'anio': '2019', 'estacion': 'Atlalilco', 'fec...
# record_timestamp                   2020-03-25T17:13:11.354000+00:00
#
#
# a_ver:  {'anio': '2019', 'estacion': 'Atlalilco', 'fecha': '2019-01-01', 'linea': 'Linea 8', 'afluencia': '6813'}
#
#
# nuevo:     anio   estacion       fecha    linea afluencia
# 0  2019  Atlalilco  2019-01-01  Linea 8      6813
#
#
# 40
# json_str: {"datasetid": "afluencia-diaria-del-metro-cdmx", "recordid": "ef3fadf2de53c18d30c75b7ad2d93747f30842c7", "fields": {"anio": "2019", "estacion": "Iztapalapa", "fecha": "2019-01-01", "linea": "Linea 8", "afluencia": "5521"}, "record_timestamp": "2020-03-25T17:13:11.354000+00:00"}
#
#
# el_json :                                                                    0
# datasetid                           afluencia-diaria-del-metro-cdmx
# recordid                   ef3fadf2de53c18d30c75b7ad2d93747f30842c7
# fields            {'anio': '2019', 'estacion': 'Iztapalapa', 'fe...
# record_timestamp                   2020-03-25T17:13:11.354000+00:00
#
#
# a_ver:  {'anio': '2019', 'estacion': 'Iztapalapa', 'fecha': '2019-01-01', 'linea': 'Linea 8', 'afluencia': '5521'}
#
#
# nuevo:     anio    estacion       fecha    linea afluencia
# 0  2019  Iztapalapa  2019-01-01  Linea 8      5521
#
#
# 41
# json_str: {"datasetid": "afluencia-diaria-del-metro-cdmx", "recordid": "ef3b8b3182a666ec8c38f0bc5a2f7fd4f55cdb25", "fields": {"anio": "2019", "estacion": "Puebla", "fecha": "2019-01-01", "linea": "Linea 9", "afluencia": "14122"}, "record_timestamp": "2020-03-25T17:13:11.354000+00:00"}
#
#
# el_json :                                                                    0
# datasetid                           afluencia-diaria-del-metro-cdmx
# recordid                   ef3b8b3182a666ec8c38f0bc5a2f7fd4f55cdb25
# fields            {'anio': '2019', 'estacion': 'Puebla', 'fecha'...
# record_timestamp                   2020-03-25T17:13:11.354000+00:00
#
#
# a_ver:  {'anio': '2019', 'estacion': 'Puebla', 'fecha': '2019-01-01', 'linea': 'Linea 9', 'afluencia': '14122'}
#
#
# nuevo:     anio estacion       fecha    linea afluencia
# 0  2019   Puebla  2019-01-01  Linea 9     14122
#
#
# 42
# json_str: {"datasetid": "afluencia-diaria-del-metro-cdmx", "recordid": "1b38841f9f5c74d11ea64cf8c1923b5dae8f29a0", "fields": {"anio": "2019", "estacion": "Ciudad Deportiva", "fecha": "2019-01-01", "linea": "Linea 9", "afluencia": "2088"}, "record_timestamp": "2020-03-25T17:13:11.354000+00:00"}
#
#
# el_json :                                                                    0
# datasetid                           afluencia-diaria-del-metro-cdmx
# recordid                   1b38841f9f5c74d11ea64cf8c1923b5dae8f29a0
# fields            {'anio': '2019', 'estacion': 'Ciudad Deportiva...
# record_timestamp                   2020-03-25T17:13:11.354000+00:00
#
#
# a_ver:  {'anio': '2019', 'estacion': 'Ciudad Deportiva', 'fecha': '2019-01-01', 'linea': 'Linea 9', 'afluencia': '2088'}
#
#
# nuevo:     anio          estacion       fecha    linea afluencia
# 0  2019  Ciudad Deportiva  2019-01-01  Linea 9      2088
#
#
# 43
# json_str: {"datasetid": "afluencia-diaria-del-metro-cdmx", "recordid": "a120bf93114ed40980839c07cc7de2d5d23fd403", "fields": {"anio": "2019", "estacion": "L\u00e1zaro C\u00e1rdenas", "fecha": "2019-01-01", "linea": "Linea 9", "afluencia": "3784"}, "record_timestamp": "2020-03-25T17:13:11.354000+00:00"}
#
#
# el_json :                                                                    0
# datasetid                           afluencia-diaria-del-metro-cdmx
# recordid                   a120bf93114ed40980839c07cc7de2d5d23fd403
# fields            {'anio': '2019', 'estacion': 'Lázaro Cárdenas'...
# record_timestamp                   2020-03-25T17:13:11.354000+00:00
#
#
# a_ver:  {'anio': '2019', 'estacion': 'Lázaro Cárdenas', 'fecha': '2019-01-01', 'linea': 'Linea 9', 'afluencia': '3784'}
#
#
# nuevo:     anio         estacion       fecha    linea afluencia
# 0  2019  Lázaro Cárdenas  2019-01-01  Linea 9      3784
#
#
# 44
# json_str: {"datasetid": "afluencia-diaria-del-metro-cdmx", "recordid": "1027db1e15dee16bceaf48b518b30a8041733eaa", "fields": {"anio": "2019", "estacion": "Patriotismo", "fecha": "2019-01-01", "linea": "Linea 9", "afluencia": "7945"}, "record_timestamp": "2020-03-25T17:13:11.354000+00:00"}
#
#
# el_json :                                                                    0
# datasetid                           afluencia-diaria-del-metro-cdmx
# recordid                   1027db1e15dee16bceaf48b518b30a8041733eaa
# fields            {'anio': '2019', 'estacion': 'Patriotismo', 'f...
# record_timestamp                   2020-03-25T17:13:11.354000+00:00
#
#
# a_ver:  {'anio': '2019', 'estacion': 'Patriotismo', 'fecha': '2019-01-01', 'linea': 'Linea 9', 'afluencia': '7945'}
#
#
# nuevo:     anio     estacion       fecha    linea afluencia
# 0  2019  Patriotismo  2019-01-01  Linea 9      7945
#
#
# 45
# json_str: {"datasetid": "afluencia-diaria-del-metro-cdmx", "recordid": "b62ae20fffe2e2a1ceb7a90f1cf20ba39f0c48d5", "fields": {"anio": "2019", "estacion": "Tacubaya", "fecha": "2019-01-01", "linea": "Linea 9", "afluencia": "15023"}, "record_timestamp": "2020-03-25T17:13:11.354000+00:00"}
#
#
# el_json :                                                                    0
# datasetid                           afluencia-diaria-del-metro-cdmx
# recordid                   b62ae20fffe2e2a1ceb7a90f1cf20ba39f0c48d5
# fields            {'anio': '2019', 'estacion': 'Tacubaya', 'fech...
# record_timestamp                   2020-03-25T17:13:11.354000+00:00
#
#
# a_ver:  {'anio': '2019', 'estacion': 'Tacubaya', 'fecha': '2019-01-01', 'linea': 'Linea 9', 'afluencia': '15023'}
#
#
# nuevo:     anio  estacion       fecha    linea afluencia
# 0  2019  Tacubaya  2019-01-01  Linea 9     15023
#
#
# 46
# json_str: {"datasetid": "afluencia-diaria-del-metro-cdmx", "recordid": "e2a31bab3d9f57cc32eeac2b26459941e3ecc706", "fields": {"anio": "2019", "estacion": "Tepalcates", "fecha": "2019-01-01", "linea": "Linea A", "afluencia": "5099"}, "record_timestamp": "2020-03-25T17:13:11.354000+00:00"}
#
#
# el_json :                                                                    0
# datasetid                           afluencia-diaria-del-metro-cdmx
# recordid                   e2a31bab3d9f57cc32eeac2b26459941e3ecc706
# fields            {'anio': '2019', 'estacion': 'Tepalcates', 'fe...
# record_timestamp                   2020-03-25T17:13:11.354000+00:00
#
#
# a_ver:  {'anio': '2019', 'estacion': 'Tepalcates', 'fecha': '2019-01-01', 'linea': 'Linea A', 'afluencia': '5099'}
#
#
# nuevo:     anio    estacion       fecha    linea afluencia
# 0  2019  Tepalcates  2019-01-01  Linea A      5099
#
#
# 47
# json_str: {"datasetid": "afluencia-diaria-del-metro-cdmx", "recordid": "cfd97d771be96139fb3b6d487757dc74f83da3cc", "fields": {"anio": "2019", "estacion": "Guelatao", "fecha": "2019-01-01", "linea": "Linea A", "afluencia": "7264"}, "record_timestamp": "2020-03-25T17:13:11.354000+00:00"}
#
#
# el_json :                                                                    0
# datasetid                           afluencia-diaria-del-metro-cdmx
# recordid                   cfd97d771be96139fb3b6d487757dc74f83da3cc
# fields            {'anio': '2019', 'estacion': 'Guelatao', 'fech...
# record_timestamp                   2020-03-25T17:13:11.354000+00:00
#
#
# a_ver:  {'anio': '2019', 'estacion': 'Guelatao', 'fecha': '2019-01-01', 'linea': 'Linea A', 'afluencia': '7264'}
#
#
# nuevo:     anio  estacion       fecha    linea afluencia
# 0  2019  Guelatao  2019-01-01  Linea A      7264
#
#
# 48
# json_str: {"datasetid": "afluencia-diaria-del-metro-cdmx", "recordid": "3dd2c8ff2b58e0cd372849f201c831084368a82f", "fields": {"anio": "2019", "estacion": "Santa Marta", "fecha": "2019-01-01", "linea": "Linea A", "afluencia": "16024"}, "record_timestamp": "2020-03-25T17:13:11.354000+00:00"}
#
#
# el_json :                                                                    0
# datasetid                           afluencia-diaria-del-metro-cdmx
# recordid                   3dd2c8ff2b58e0cd372849f201c831084368a82f
# fields            {'anio': '2019', 'estacion': 'Santa Marta', 'f...
# record_timestamp                   2020-03-25T17:13:11.354000+00:00
#
#
# a_ver:  {'anio': '2019', 'estacion': 'Santa Marta', 'fecha': '2019-01-01', 'linea': 'Linea A', 'afluencia': '16024'}
#
#
# nuevo:     anio     estacion       fecha    linea afluencia
# 0  2019  Santa Marta  2019-01-01  Linea A     16024
#
#
# 49
# json_str: {"datasetid": "afluencia-diaria-del-metro-cdmx", "recordid": "7cc303d1f24be7f32071fe557cb24f678f828b9f", "fields": {"anio": "2019", "estacion": "La Paz", "fecha": "2019-01-01", "linea": "Linea A", "afluencia": "18634"}, "record_timestamp": "2020-03-25T17:13:11.354000+00:00"}
#
#
# el_json :                                                                    0
# datasetid                           afluencia-diaria-del-metro-cdmx
# recordid                   7cc303d1f24be7f32071fe557cb24f678f828b9f
# fields            {'anio': '2019', 'estacion': 'La Paz', 'fecha'...
# record_timestamp                   2020-03-25T17:13:11.354000+00:00
#
#
# a_ver:  {'anio': '2019', 'estacion': 'La Paz', 'fecha': '2019-01-01', 'linea': 'Linea A', 'afluencia': '18634'}
#
#
# nuevo:     anio estacion       fecha    linea afluencia
# 0  2019   La Paz  2019-01-01  Linea A     18634
#
#
# 50
# json_str: {"datasetid": "afluencia-diaria-del-metro-cdmx", "recordid": "445600895e80610e1b360b534bc3e71cd299f66a", "fields": {"anio": "2019", "estacion": "Lagunilla", "fecha": "2019-01-01", "linea": "Linea B", "afluencia": "8091"}, "record_timestamp": "2020-03-25T17:13:11.354000+00:00"}
#
#
# el_json :                                                                    0
# datasetid                           afluencia-diaria-del-metro-cdmx
# recordid                   445600895e80610e1b360b534bc3e71cd299f66a
# fields            {'anio': '2019', 'estacion': 'Lagunilla', 'fec...
# record_timestamp                   2020-03-25T17:13:11.354000+00:00
#
#
# a_ver:  {'anio': '2019', 'estacion': 'Lagunilla', 'fecha': '2019-01-01', 'linea': 'Linea B', 'afluencia': '8091'}
#
#
# nuevo:     anio   estacion       fecha    linea afluencia
# 0  2019  Lagunilla  2019-01-01  Linea B      8091
#
#
# 51
# json_str: {"datasetid": "afluencia-diaria-del-metro-cdmx", "recordid": "6ebd7d1b3e9258d69b2c8e9f0c82bb7f14f5292a", "fields": {"anio": "2019", "estacion": "Tepito", "fecha": "2019-01-01", "linea": "Linea B", "afluencia": "10246"}, "record_timestamp": "2020-03-25T17:13:11.354000+00:00"}
#
#
# el_json :                                                                    0
# datasetid                           afluencia-diaria-del-metro-cdmx
# recordid                   6ebd7d1b3e9258d69b2c8e9f0c82bb7f14f5292a
# fields            {'anio': '2019', 'estacion': 'Tepito', 'fecha'...
# record_timestamp                   2020-03-25T17:13:11.354000+00:00
#
#
# a_ver:  {'anio': '2019', 'estacion': 'Tepito', 'fecha': '2019-01-01', 'linea': 'Linea B', 'afluencia': '10246'}
#
#
# nuevo:     anio estacion       fecha    linea afluencia
# 0  2019   Tepito  2019-01-01  Linea B     10246
#
#
# 52
# json_str: {"datasetid": "afluencia-diaria-del-metro-cdmx", "recordid": "b6bcb060d096e69be5c067b89089626b7dfcf500", "fields": {"anio": "2019", "estacion": "Morelos", "fecha": "2019-01-01", "linea": "Linea B", "afluencia": "3400"}, "record_timestamp": "2020-03-25T17:13:11.354000+00:00"}
#
#
# el_json :                                                                    0
# datasetid                           afluencia-diaria-del-metro-cdmx
# recordid                   b6bcb060d096e69be5c067b89089626b7dfcf500
# fields            {'anio': '2019', 'estacion': 'Morelos', 'fecha...
# record_timestamp                   2020-03-25T17:13:11.354000+00:00
#
#
# a_ver:  {'anio': '2019', 'estacion': 'Morelos', 'fecha': '2019-01-01', 'linea': 'Linea B', 'afluencia': '3400'}
#
#
# nuevo:     anio estacion       fecha    linea afluencia
# 0  2019  Morelos  2019-01-01  Linea B      3400
#
#
# 53
# json_str: {"datasetid": "afluencia-diaria-del-metro-cdmx", "recordid": "9549794b22e8abbe01fd6429e9474e4bedf66676", "fields": {"anio": "2019", "estacion": "Ricardo Flores Mag\u00f3n", "fecha": "2019-01-01", "linea": "Linea B", "afluencia": "2207"}, "record_timestamp": "2020-03-25T17:13:11.354000+00:00"}
#
#
# el_json :                                                                    0
# datasetid                           afluencia-diaria-del-metro-cdmx
# recordid                   9549794b22e8abbe01fd6429e9474e4bedf66676
# fields            {'anio': '2019', 'estacion': 'Ricardo Flores M...
# record_timestamp                   2020-03-25T17:13:11.354000+00:00
#
#
# a_ver:  {'anio': '2019', 'estacion': 'Ricardo Flores Magón', 'fecha': '2019-01-01', 'linea': 'Linea B', 'afluencia': '2207'}
#
#
# nuevo:     anio              estacion       fecha    linea afluencia
# 0  2019  Ricardo Flores Magón  2019-01-01  Linea B      2207
#
#
# 54
# json_str: {"datasetid": "afluencia-diaria-del-metro-cdmx", "recordid": "77646c7b5d06ca19b905982d48f13108f17b3a9e", "fields": {"anio": "2019", "estacion": "Deportivo Ocean\u00eda", "fecha": "2019-01-01", "linea": "Linea B", "afluencia": "5280"}, "record_timestamp": "2020-03-25T17:13:11.354000+00:00"}
#
#
# el_json :                                                                    0
# datasetid                           afluencia-diaria-del-metro-cdmx
# recordid                   77646c7b5d06ca19b905982d48f13108f17b3a9e
# ...
# 0  2019  Cerro de la Estrella  2019-01-01  Linea 8      3963
#
#
# 177
# json_str: {"datasetid": "afluencia-diaria-del-metro-cdmx", "recordid": "88b7dc83e19ca8ebe83b9bf814e86ed0e24c5f9e", "fields": {"anio": "2019", "estacion": "U A M  I", "fecha": "2019-01-01", "linea": "Linea 8", "afluencia": "7604"}, "record_timestamp": "2020-03-25T17:13:11.354000+00:00"}
#
#
# el_json :                                                                    0
# datasetid                           afluencia-diaria-del-metro-cdmx
# recordid                   88b7dc83e19ca8ebe83b9bf814e86ed0e24c5f9e
# fields            {'anio': '2019', 'estacion': 'U A M  I', 'fech...
# record_timestamp                   2020-03-25T17:13:11.354000+00:00
#
#
# a_ver:  {'anio': '2019', 'estacion': 'U A M  I', 'fecha': '2019-01-01', 'linea': 'Linea 8', 'afluencia': '7604'}
#
#
# nuevo:     anio  estacion       fecha    linea afluencia
# 0  2019  U A M  I  2019-01-01  Linea 8      7604
#
#
# 178
# json_str: {"datasetid": "afluencia-diaria-del-metro-cdmx", "recordid": "867905ad0dc364d163359319142aa1d5fe939e08", "fields": {"anio": "2019", "estacion": "Constituci\u00f3n de 1917", "fecha": "2019-01-01", "linea": "Linea 8", "afluencia": "28990"}, "record_timestamp": "2020-03-25T17:13:11.354000+00:00"}
#
#
# el_json :                                                                    0
# datasetid                           afluencia-diaria-del-metro-cdmx
# recordid                   867905ad0dc364d163359319142aa1d5fe939e08
# fields            {'anio': '2019', 'estacion': 'Constitución de ...
# record_timestamp                   2020-03-25T17:13:11.354000+00:00
#
#
# a_ver:  {'anio': '2019', 'estacion': 'Constitución de 1917', 'fecha': '2019-01-01', 'linea': 'Linea 8', 'afluencia': '28990'}
#
#
# nuevo:     anio              estacion       fecha    linea afluencia
# 0  2019  Constitución de 1917  2019-01-01  Linea 8     28990
#
#
# 179
# json_str: {"datasetid": "afluencia-diaria-del-metro-cdmx", "recordid": "9959b9b4f6a9fe76db9d832363209076cdf6f311", "fields": {"anio": "2019", "estacion": "Pantitl\u00e1n", "fecha": "2019-01-01", "linea": "Linea 9", "afluencia": "19084"}, "record_timestamp": "2020-03-25T17:13:11.354000+00:00"}
#
#
# el_json :                                                                    0
# datasetid                           afluencia-diaria-del-metro-cdmx
# recordid                   9959b9b4f6a9fe76db9d832363209076cdf6f311
# fields            {'anio': '2019', 'estacion': 'Pantitlán', 'fec...
# record_timestamp                   2020-03-25T17:13:11.354000+00:00
#
#
# a_ver:  {'anio': '2019', 'estacion': 'Pantitlán', 'fecha': '2019-01-01', 'linea': 'Linea 9', 'afluencia': '19084'}
#
#
# nuevo:     anio   estacion       fecha    linea afluencia
# 0  2019  Pantitlán  2019-01-01  Linea 9     19084
#
#
# 180
# json_str: {"datasetid": "afluencia-diaria-del-metro-cdmx", "recordid": "8879c722bd18d2fc24d41649b0433288a6013ad0", "fields": {"anio": "2019", "estacion": "Mixiuhca", "fecha": "2019-01-01", "linea": "Linea 9", "afluencia": "4786"}, "record_timestamp": "2020-03-25T17:13:11.354000+00:00"}
#
#
# el_json :                                                                    0
# datasetid                           afluencia-diaria-del-metro-cdmx
# recordid                   8879c722bd18d2fc24d41649b0433288a6013ad0
# fields            {'anio': '2019', 'estacion': 'Mixiuhca', 'fech...
# record_timestamp                   2020-03-25T17:13:11.354000+00:00
#
#
# a_ver:  {'anio': '2019', 'estacion': 'Mixiuhca', 'fecha': '2019-01-01', 'linea': 'Linea 9', 'afluencia': '4786'}
#
#
# nuevo:     anio  estacion       fecha    linea afluencia
# 0  2019  Mixiuhca  2019-01-01  Linea 9      4786
#
#
# 181
# json_str: {"datasetid": "afluencia-diaria-del-metro-cdmx", "recordid": "631e600dc8fcb01fa5eedf9837f1370849cc3396", "fields": {"anio": "2019", "estacion": "Jamaica", "fecha": "2019-01-01", "linea": "Linea 9", "afluencia": "4056"}, "record_timestamp": "2020-03-25T17:13:11.354000+00:00"}
#
#
# el_json :                                                                    0
# datasetid                           afluencia-diaria-del-metro-cdmx
# recordid                   631e600dc8fcb01fa5eedf9837f1370849cc3396
# fields            {'anio': '2019', 'estacion': 'Jamaica', 'fecha...
# record_timestamp                   2020-03-25T17:13:11.354000+00:00
#
#
# a_ver:  {'anio': '2019', 'estacion': 'Jamaica', 'fecha': '2019-01-01', 'linea': 'Linea 9', 'afluencia': '4056'}
#
#
# nuevo:     anio estacion       fecha    linea afluencia
# 0  2019  Jamaica  2019-01-01  Linea 9      4056
#
#
# 182
# json_str: {"datasetid": "afluencia-diaria-del-metro-cdmx", "recordid": "eb2799ae68574c604f5c0473317664434fae1fea", "fields": {"anio": "2019", "estacion": "Canal de San Juan", "fecha": "2019-01-01", "linea": "Linea A", "afluencia": "5069"}, "record_timestamp": "2020-03-25T17:13:11.354000+00:00"}
#
#
# el_json :                                                                    0
# datasetid                           afluencia-diaria-del-metro-cdmx
# recordid                   eb2799ae68574c604f5c0473317664434fae1fea
# fields            {'anio': '2019', 'estacion': 'Canal de San Jua...
# record_timestamp                   2020-03-25T17:13:11.354000+00:00
#
#
# a_ver:  {'anio': '2019', 'estacion': 'Canal de San Juan', 'fecha': '2019-01-01', 'linea': 'Linea A', 'afluencia': '5069'}
#
#
# nuevo:     anio           estacion       fecha    linea afluencia
# 0  2019  Canal de San Juan  2019-01-01  Linea A      5069
#
#
# 183
# json_str: {"datasetid": "afluencia-diaria-del-metro-cdmx", "recordid": "3f90e1546241497d651e758f8ca0b3fb716fc241", "fields": {"anio": "2019", "estacion": "Pe\u00f1\u00f3n Viejo", "fecha": "2019-01-01", "linea": "Linea A", "afluencia": "6312"}, "record_timestamp": "2020-03-25T17:13:11.354000+00:00"}
#
#
# el_json :                                                                    0
# datasetid                           afluencia-diaria-del-metro-cdmx
# recordid                   3f90e1546241497d651e758f8ca0b3fb716fc241
# fields            {'anio': '2019', 'estacion': 'Peñón Viejo', 'f...
# record_timestamp                   2020-03-25T17:13:11.354000+00:00
#
#
# a_ver:  {'anio': '2019', 'estacion': 'Peñón Viejo', 'fecha': '2019-01-01', 'linea': 'Linea A', 'afluencia': '6312'}
#
#
# nuevo:     anio     estacion       fecha    linea afluencia
# 0  2019  Peñón Viejo  2019-01-01  Linea A      6312
#
#
# 184
# json_str: {"datasetid": "afluencia-diaria-del-metro-cdmx", "recordid": "dae2c613c3dd680748828c0b853bcc051edf7b19", "fields": {"anio": "2019", "estacion": "Los Reyes", "fecha": "2019-01-01", "linea": "Linea A", "afluencia": "8199"}, "record_timestamp": "2020-03-25T17:13:11.354000+00:00"}
#
#
# el_json :                                                                    0
# datasetid                           afluencia-diaria-del-metro-cdmx
# recordid                   dae2c613c3dd680748828c0b853bcc051edf7b19
# fields            {'anio': '2019', 'estacion': 'Los Reyes', 'fec...
# record_timestamp                   2020-03-25T17:13:11.354000+00:00
#
#
# a_ver:  {'anio': '2019', 'estacion': 'Los Reyes', 'fecha': '2019-01-01', 'linea': 'Linea A', 'afluencia': '8199'}
#
#
# nuevo:     anio   estacion       fecha    linea afluencia
# 0  2019  Los Reyes  2019-01-01  Linea A      8199
#
#
# 185
# json_str: {"datasetid": "afluencia-diaria-del-metro-cdmx", "recordid": "c9911a9b8526047e4eae5caccd414ee55a000b34", "fields": {"anio": "2019", "estacion": "Buenavista", "fecha": "2019-01-01", "linea": "Linea B", "afluencia": "28880"}, "record_timestamp": "2020-03-25T17:13:11.354000+00:00"}
#
#
# el_json :                                                                    0
# datasetid                           afluencia-diaria-del-metro-cdmx
# recordid                   c9911a9b8526047e4eae5caccd414ee55a000b34
# fields            {'anio': '2019', 'estacion': 'Buenavista', 'fe...
# record_timestamp                   2020-03-25T17:13:11.354000+00:00
#
#
# a_ver:  {'anio': '2019', 'estacion': 'Buenavista', 'fecha': '2019-01-01', 'linea': 'Linea B', 'afluencia': '28880'}
#
#
# nuevo:     anio    estacion       fecha    linea afluencia
# 0  2019  Buenavista  2019-01-01  Linea B     28880
#
#
# 186
# json_str: {"datasetid": "afluencia-diaria-del-metro-cdmx", "recordid": "14e3bde5d79070252b624e73cd91c1b8c67e9d42", "fields": {"anio": "2019", "estacion": "Garibaldi", "fecha": "2019-01-01", "linea": "Linea B", "afluencia": "2465"}, "record_timestamp": "2020-03-25T17:13:11.354000+00:00"}
#
#
# el_json :                                                                    0
# datasetid                           afluencia-diaria-del-metro-cdmx
# recordid                   14e3bde5d79070252b624e73cd91c1b8c67e9d42
# fields            {'anio': '2019', 'estacion': 'Garibaldi', 'fec...
# record_timestamp                   2020-03-25T17:13:11.354000+00:00
#
#
# a_ver:  {'anio': '2019', 'estacion': 'Garibaldi', 'fecha': '2019-01-01', 'linea': 'Linea B', 'afluencia': '2465'}
#
#
# nuevo:     anio   estacion       fecha    linea afluencia
# 0  2019  Garibaldi  2019-01-01  Linea B      2465
#
#
# 187
# json_str: {"datasetid": "afluencia-diaria-del-metro-cdmx", "recordid": "b46f157589096da55f985c36e2777ba6840136dd", "fields": {"anio": "2019", "estacion": "San L\u00e1zaro", "fecha": "2019-01-01", "linea": "Linea B", "afluencia": "9904"}, "record_timestamp": "2020-03-25T17:13:11.354000+00:00"}
#
#
# el_json :                                                                    0
# datasetid                           afluencia-diaria-del-metro-cdmx
# recordid                   b46f157589096da55f985c36e2777ba6840136dd
# fields            {'anio': '2019', 'estacion': 'San Lázaro', 'fe...
# record_timestamp                   2020-03-25T17:13:11.354000+00:00
#
#
# a_ver:  {'anio': '2019', 'estacion': 'San Lázaro', 'fecha': '2019-01-01', 'linea': 'Linea B', 'afluencia': '9904'}
#
#
# nuevo:     anio    estacion       fecha    linea afluencia
# 0  2019  San Lázaro  2019-01-01  Linea B      9904
#
#
# 188
# json_str: {"datasetid": "afluencia-diaria-del-metro-cdmx", "recordid": "c454443df924d8758095a33b64f5205de5df3729", "fields": {"anio": "2019", "estacion": "R\u00edo de los Remedios", "fecha": "2019-01-01", "linea": "Linea B", "afluencia": "8678"}, "record_timestamp": "2020-03-25T17:13:11.354000+00:00"}
#
#
# el_json :                                                                    0
# datasetid                           afluencia-diaria-del-metro-cdmx
# recordid                   c454443df924d8758095a33b64f5205de5df3729
# fields            {'anio': '2019', 'estacion': 'Río de los Remed...
# record_timestamp                   2020-03-25T17:13:11.354000+00:00
#
#
# a_ver:  {'anio': '2019', 'estacion': 'Río de los Remedios', 'fecha': '2019-01-01', 'linea': 'Linea B', 'afluencia': '8678'}
#
#
# nuevo:     anio             estacion       fecha    linea afluencia
# 0  2019  Río de los Remedios  2019-01-01  Linea B      8678
#
#
# 189
# json_str: {"datasetid": "afluencia-diaria-del-metro-cdmx", "recordid": "546a80883bd07af84e8a5d54e8978639aa7bdf83", "fields": {"anio": "2019", "estacion": "M\u00fazquiz", "fecha": "2019-01-01", "linea": "Linea B", "afluencia": "15138"}, "record_timestamp": "2020-03-25T17:13:11.354000+00:00"}
#
#
# el_json :                                                                    0
# datasetid                           afluencia-diaria-del-metro-cdmx
# recordid                   546a80883bd07af84e8a5d54e8978639aa7bdf83
# fields            {'anio': '2019', 'estacion': 'Múzquiz', 'fecha...
# record_timestamp                   2020-03-25T17:13:11.354000+00:00
#
#
# a_ver:  {'anio': '2019', 'estacion': 'Múzquiz', 'fecha': '2019-01-01', 'linea': 'Linea B', 'afluencia': '15138'}
#
#
# nuevo:     anio estacion       fecha    linea afluencia
# 0  2019  Múzquiz  2019-01-01  Linea B     15138
#
#
# 190
# json_str: {"datasetid": "afluencia-diaria-del-metro-cdmx", "recordid": "499ba79580342017d31a0a3a6beab2f7c20e09fe", "fields": {"anio": "2019", "estacion": "Ciudad Azteca", "fecha": "2019-01-01", "linea": "Linea B", "afluencia": "27091"}, "record_timestamp": "2020-03-25T17:13:11.354000+00:00"}
#
#
# el_json :                                                                    0
# datasetid                           afluencia-diaria-del-metro-cdmx
# recordid                   499ba79580342017d31a0a3a6beab2f7c20e09fe
# fields            {'anio': '2019', 'estacion': 'Ciudad Azteca', ...
# record_timestamp                   2020-03-25T17:13:11.354000+00:00
#
#
# a_ver:  {'anio': '2019', 'estacion': 'Ciudad Azteca', 'fecha': '2019-01-01', 'linea': 'Linea B', 'afluencia': '27091'}
#
#
# nuevo:     anio       estacion       fecha    linea afluencia
# 0  2019  Ciudad Azteca  2019-01-01  Linea B     27091
#
#
# 191
# json_str: {"datasetid": "afluencia-diaria-del-metro-cdmx", "recordid": "54885322cc02e19605819d86f714aaff4827f626", "fields": {"anio": "2019", "estacion": "Tl\u00e1huac", "fecha": "2019-01-01", "linea": "Linea 12", "afluencia": "18241"}, "record_timestamp": "2020-03-25T17:13:11.354000+00:00"}
#
#
# el_json :                                                                    0
# datasetid                           afluencia-diaria-del-metro-cdmx
# recordid                   54885322cc02e19605819d86f714aaff4827f626
# fields            {'anio': '2019', 'estacion': 'Tláhuac', 'fecha...
# record_timestamp                   2020-03-25T17:13:11.354000+00:00
#
#
# a_ver:  {'anio': '2019', 'estacion': 'Tláhuac', 'fecha': '2019-01-01', 'linea': 'Linea 12', 'afluencia': '18241'}
#
#
# nuevo:     anio estacion       fecha     linea afluencia
# 0  2019  Tláhuac  2019-01-01  Linea 12     18241
#
#
# 192
# json_str: {"datasetid": "afluencia-diaria-del-metro-cdmx", "recordid": "db35fd20096fdcf48ab1891198f50d2265b0c9f4", "fields": {"anio": "2019", "estacion": "Tlaltenco", "fecha": "2019-01-01", "linea": "Linea 12", "afluencia": "1397"}, "record_timestamp": "2020-03-25T17:13:11.354000+00:00"}
#
#
# el_json :                                                                    0
# datasetid                           afluencia-diaria-del-metro-cdmx
# recordid                   db35fd20096fdcf48ab1891198f50d2265b0c9f4
# fields            {'anio': '2019', 'estacion': 'Tlaltenco', 'fec...
# record_timestamp                   2020-03-25T17:13:11.354000+00:00
#
#
# a_ver:  {'anio': '2019', 'estacion': 'Tlaltenco', 'fecha': '2019-01-01', 'linea': 'Linea 12', 'afluencia': '1397'}
#
#
# nuevo:     anio   estacion       fecha     linea afluencia
# 0  2019  Tlaltenco  2019-01-01  Linea 12      1397
#
#
# 193
# json_str: {"datasetid": "afluencia-diaria-del-metro-cdmx", "recordid": "bd97a5166441502c80fd0a6613f9ac22ee92a08c", "fields": {"anio": "2019", "estacion": "Zapotitl\u00e1n", "fecha": "2019-01-01", "linea": "Linea 12", "afluencia": "5459"}, "record_timestamp": "2020-03-25T17:13:11.354000+00:00"}
#
#
# el_json :                                                                    0
# datasetid                           afluencia-diaria-del-metro-cdmx
# recordid                   bd97a5166441502c80fd0a6613f9ac22ee92a08c
# fields            {'anio': '2019', 'estacion': 'Zapotitlán', 'fe...
# record_timestamp                   2020-03-25T17:13:11.354000+00:00
#
#
# a_ver:  {'anio': '2019', 'estacion': 'Zapotitlán', 'fecha': '2019-01-01', 'linea': 'Linea 12', 'afluencia': '5459'}
#
#
# nuevo:     anio    estacion       fecha     linea afluencia
# 0  2019  Zapotitlán  2019-01-01  Linea 12      5459
#
#
# 194
# json_str: {"datasetid": "afluencia-diaria-del-metro-cdmx", "recordid": "4674d6c5cbe31bf874d3a75a8f69e5da46284d3d", "fields": {"anio": "2019", "estacion": "Calle 11", "fecha": "2019-01-01", "linea": "Linea 12", "afluencia": "4170"}, "record_timestamp": "2020-03-25T17:13:11.354000+00:00"}
#
#
# el_json :                                                                    0
# datasetid                           afluencia-diaria-del-metro-cdmx
# recordid                   4674d6c5cbe31bf874d3a75a8f69e5da46284d3d
# fields            {'anio': '2019', 'estacion': 'Calle 11', 'fech...
# record_timestamp                   2020-03-25T17:13:11.354000+00:00
#
#
# a_ver:  {'anio': '2019', 'estacion': 'Calle 11', 'fecha': '2019-01-01', 'linea': 'Linea 12', 'afluencia': '4170'}
#
#
# nuevo:     anio  estacion       fecha     linea afluencia
# 0  2019  Calle 11  2019-01-01  Linea 12      4170

# %%
f.head()
# Out:
# Empty DataFrame
# Columns: [anio, estacion, fecha, linea, afluencia]
# Index: []

# %%
i=0
while i < (len(list(dfrec))):
    json_str = json.dumps(dfrec[i])
    el_json=pd.read_json(json_str,orient='index',encoding='utf-8')
    a_ver = (el_json.loc['fields'][0])
    nuevo=pd.DataFrame(a_ver,index=[0])
    f.append(nuevo)
    i=i+1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-289-76904ec9c6c6> in <module>
#       2 while i < (len(list(dfrec))):
#       3     json_str = json.dumps(list(dfrec[i]))
# ----> 4     el_json=pd.read_json(json_str,orient='index',encoding='utf-8')
#       5     a_ver = (el_json.loc['fields'][0])
#       6     nuevo=pd.DataFrame(a_ver,index=[0])
#
# ~/.pyenv/versions/3.8.2/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     212                 else:
#     213                     kwargs[new_arg_name] = new_arg_value
# --> 214             return func(*args, **kwargs)
#     215
#     216         return cast(F, wrapper)
#
# ~/.pyenv/versions/3.8.2/lib/python3.8/site-packages/pandas/io/json/_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     606         return json_reader
#     607
# --> 608     result = json_reader.read()
#     609     if should_close:
#     610         filepath_or_buffer.close()
#
# ~/.pyenv/versions/3.8.2/lib/python3.8/site-packages/pandas/io/json/_json.py in read(self)
#     729             obj = self._get_object_parser(self._combine_lines(data.split("\n")))
#     730         else:
# --> 731             obj = self._get_object_parser(self.data)
#     732         self.close()
#     733         return obj
#
# ~/.pyenv/versions/3.8.2/lib/python3.8/site-packages/pandas/io/json/_json.py in _get_object_parser(self, json)
#     751         obj = None
#     752         if typ == "frame":
# --> 753             obj = FrameParser(json, **kwargs).parse()
#     754
#     755         if typ == "series" or obj is None:
#
# ~/.pyenv/versions/3.8.2/lib/python3.8/site-packages/pandas/io/json/_json.py in parse(self)
#     855
#     856         else:
# --> 857             self._parse_no_numpy()
#     858
#     859         if self.obj is None:
#
# ~/.pyenv/versions/3.8.2/lib/python3.8/site-packages/pandas/io/json/_json.py in _parse_no_numpy(self)
#    1097             self.obj = DataFrame(dtype=None, **decoded)
#    1098         elif orient == "index":
# -> 1099             self.obj = DataFrame.from_dict(
#    1100                 loads(json, precise_float=self.precise_float),
#    1101                 dtype=None,
#
# ~/.pyenv/versions/3.8.2/lib/python3.8/site-packages/pandas/core/frame.py in from_dict(cls, data, orient, dtype, columns)
#    1235             if len(data) > 0:
#    1236                 # TODO speed up Series case
# -> 1237                 if isinstance(list(data.values())[0], (Series, dict)):
#    1238                     data = _from_nested_dict(data)
#    1239                 else:
#
# AttributeError: 'list' object has no attribute 'values'

# %%
list(dfrec)[2]
# Out:
# {'datasetid': 'afluencia-diaria-del-metro-cdmx',
#  'recordid': '25d2093306fd85bc965fb11b8d10b8bce12688aa',
#  'fields': {'anio': '2019',
#   'estacion': 'Blvd. Puerto Aéreo',
#   'fecha': '2019-01-01',
#   'linea': 'Linea 1',
#   'afluencia': '12613'},
#  'record_timestamp': '2020-03-25T17:13:11.354000+00:00'}

# %%
range(len(dfrec))
# Out:
# range(0, 195)

# %%
len(list(dfrec))
# Out:
# 195

# %%
df.head()
# Out:
#    nhits                                         parameters  \
# 0    195  {'dataset': 'afluencia-diaria-del-metro-cdmx',...
#
#                                              records  \
# 0  [{'datasetid': 'afluencia-diaria-del-metro-cdm...
#
#                                         facet_groups
# 0  [{'facets': [{'count': 195, 'path': '2019', 's...

# %%
df
# Out:
#    nhits                                         parameters  \
# 0    195  {'dataset': 'afluencia-diaria-del-metro-cdmx',...
#
#                                              records  \
# 0  [{'datasetid': 'afluencia-diaria-del-metro-cdm...
#
#                                         facet_groups
# 0  [{'facets': [{'count': 195, 'path': '2019', 's...

# %%
dfparams=df['parameters'][0]

# %%
dfparams
# Out:
# {'dataset': 'afluencia-diaria-del-metro-cdmx',
#  'refine': {'fecha': '2019-01-01'},
#  'timezone': 'UTC',
#  'rows': 10000,
#  'sort': ['-fecha'],
#  'format': 'json'}

# %%
dfacet_groups=df['facet_groups'][0]
dfacet_groups
# Out:
# [{'facets': [{'count': 195,
#     'path': '2019',
#     'state': 'displayed',
#     'name': '2019'}],
#   'name': 'fecha'}]

# %%
prueba=dfacet_groups[0]

# %%
prueba.get('facets')
# Out:
# [{'count': 195, 'path': '2019', 'state': 'displayed', 'name': '2019'}]

# %%
prueba.get('facets')[0].get('count')
# Out:
# 195

# %%
with open('metro_2019-01-01.json') as complex_data:
    data = complex_data.read()
    numbers = json.loads(data)

# %%
data[10:13]
# Out:
# '195'

# %%
#numbers

# %%
pd.read_json(json_str,orient='records') #ec33a8dcf83dba40ce9b09e1f51f67acefe1a0ef
# Out:
#                                  datasetid  \
# afluencia  afluencia-diaria-del-metro-cdmx
# anio       afluencia-diaria-del-metro-cdmx
# estacion   afluencia-diaria-del-metro-cdmx
# fecha      afluencia-diaria-del-metro-cdmx
# linea      afluencia-diaria-del-metro-cdmx
#
#                                            recordid      fields  \
# afluencia  400086b6463bbfe0151467f1e9ace23c6e4e5781       22076
# anio       400086b6463bbfe0151467f1e9ace23c6e4e5781        2019
# estacion   400086b6463bbfe0151467f1e9ace23c6e4e5781    Zaragoza
# fecha      400086b6463bbfe0151467f1e9ace23c6e4e5781  2019-01-01
# linea      400086b6463bbfe0151467f1e9ace23c6e4e5781     Linea 1
#
#                            record_timestamp
# afluencia  2020-03-25T17:13:11.354000+00:00
# anio       2020-03-25T17:13:11.354000+00:00
# estacion   2020-03-25T17:13:11.354000+00:00
# fecha      2020-03-25T17:13:11.354000+00:00
# linea      2020-03-25T17:13:11.354000+00:00

# %%
el_json[0].dtype
# Out:
# dtype('O')

# %%
el_json[0]
# Out:
# datasetid                             afluencia-diaria-del-metro-cdmx
# recordid                     ec33a8dcf83dba40ce9b09e1f51f67acefe1a0ef
# fields              {'anio': '2019', 'estacion': 'Pantitlán', 'fec...
# record_timestamp                     2020-03-25T17:13:11.354000+00:00
# Name: 0, dtype: object

# %%
el_json[:'fields']
# Out:
#                                                            0
# datasetid                    afluencia-diaria-del-metro-cdmx
# recordid            ec33a8dcf83dba40ce9b09e1f51f67acefe1a0ef
# fields     {'anio': '2019', 'estacion': 'Pantitlán', 'fec...

# %%
el_json.loc['fields']
# Out:
# 0    {'anio': '2019', 'estacion': 'Pantitlán', 'fec...
# Name: fields, dtype: object

# %%
el_json.loc['fields'].shape
# Out:
# (1,)

# %%
el_json.loc['fields'].dtype
# Out:
# dtype('O')

# %%
type(el_json.loc['fields'])
# Out:
# pandas.core.series.Series

# %%
el_json.loc['fields'][0]
# Out:
# {'anio': '2019',
#  'estacion': 'Pantitlán',
#  'fecha': '2019-01-01',
#  'linea': 'Linea 1',
#  'afluencia': '14452'}

# %%
f.add(a_ver)
# Out:
# Empty DataFrame
# Columns: [anio, estacion, fecha, linea, afluencia]
# Index: []

# %%
import numpy as np

# %%
holis=np.row_stack([a_ver])
holis
# Out:
# array([[{'anio': '2019', 'estacion': 'Pantitlán', 'fecha': '2019-01-01', 'linea': 'Linea 1', 'afluencia': '14452'}]],
#       dtype=object)

# %%
#anio,estacion,fecha,linea,afluencia =holis

# %%
type(a_ver)
# Out:
# dict

# %%
f.columns
# Out:
# Index(['anio', 'estacion', 'fecha', 'linea', 'afluencia'], dtype='object')

# %%
nuevo
# Out:
#    anio   estacion       fecha    linea afluencia
# 0  2019  Pantitlán  2019-01-01  Linea 1     14452

# %%
nuevo.columns
# Out:
# Index(['anio', 'estacion', 'fecha', 'linea', 'afluencia'], dtype='object')

# %%
f.columns=nuevo.columns

# %%
f.columns
# Out:
# Index(['anio', 'estacion', 'fecha', 'linea', 'afluencia'], dtype='object')

# %%
f.append(nuevo)
# Out:
#    anio   estacion       fecha    linea afluencia
# 0  2019  Pantitlán  2019-01-01  Linea 1     14452
